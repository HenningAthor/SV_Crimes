# %%
crimes <- read.csv("../data/crimes.csv")
crimes$population = crimes$density * crimes$area
crimes$regionOther = as.integer(as.logical(crimes$region == "other"))

crimes
# Out:
#     crimes prbarr    prbpris  polpc     density   area    taxpc    region
# 1    3901  0.289696  0.472222 0.0017868 230.71590 423.943 25.69763 central
# 2     416  0.202899  0.465753 0.0005939  97.68340 259.994 14.56088 central
# 3      91  0.406593  0.500000 0.0008209  41.27659 235.059 18.63060 west
# 4     562  0.431095  0.431373 0.0014327  48.21764 531.452 38.24473 central
# 5     170  0.631579  0.383333 0.0008353  53.05164 426.135 16.85321 west
# 6     275  0.369650  0.226415 0.0019067  59.10931 247.087 22.32144 west
# 7    1237  0.319665  0.500000 0.0012070  49.75787 827.192 20.10284 other
# 8     354  0.453258  0.489130 0.0009521  30.09986 699.270 21.63124 other
# 9     569  0.483986  0.460317 0.0013272  34.92605 874.328 24.73512 other
# 10    828  0.326196  0.404580 0.0019298  43.37209 846.973 53.86683 other
# 11   5663  0.262854  0.541096 0.0018014 246.13050 656.672 25.49358 west
# 12   2351  0.194303  0.439394 0.0014249 145.23810 507.099 17.68813 west
# ...

# %%
d_cross_validation <- function(d, dataset, formulas) {
    index <- rep(1:d, length.out=nrow(dataset))
    index <- sample(index)
    
    sep_list <- rep(0, length.out=length(formulas))
    
    for (i in 1:d) {
        test_set <- dataset[index==i, ]
        train_set <- dataset[index!=i, ]
        
        m_list <- lapply(formulas, function(formula) {glm(formula, data=train_set, family=poisson(link="log"))})
        
        for (j in 1:length(m_list)){
            model <- m_list[[j]]
            pred <- predict(model, newdata=test_set, type="response")
            sep_list[j] <- sep_list[j] + sum((test_set$crimes - pred)^2)
        }
    }
    
    msep_list = sep_list / d
    rmsep_list = sqrt(msep_list)
    
    return(data.frame(SEP=sep_list, MSEP=msep_list, RMSEP=rmsep_list))
}

# runs multiple experiments and averages over them
eval <- function(n, d, seed, dataset, formulas){
    set.seed(seed)
    seeds = floor(runif(n, min = 0, max = 10000))
    set.seed(seeds[1])
    df <- d_cross_validation(d, dataset, formulas)
    for (i in 2:n){
        set.seed(seeds[i])
        df = df + d_cross_validation(d, dataset, formulas)
    }
    return (df/n)
}

# %%
#Anfang Expertenwissen
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region"),
    as.formula("crimes ~ region + prbarr + prbpris + polpc + density + taxpc + pctymale + wcon + wser + wtrd"),
    as.formula("crimes ~ region + prbarr + prbpris + polpc + density + taxpc + pctymale + wcon + wser + wtrd + area + polpc:area + area:density")))
# Out:
#   SEP        MSEP      RMSEP
# 1 2170530515 241170057 15528.77
# 2 7163568325 795952036 26816.92
# 3 5377690266 597521141 23746.69

# %%
#Verfeinerung Expertenwissen
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region + prbarr + polpc + density + taxpc + pctymale + wcon + wser + wtrd + polpc:area + area:density"),
    as.formula("crimes ~ region + I(log(prbarr)) + prbpris + I(prbpris^2) + polpc + I(polpc^2) + I(sqrt(density)) + taxpc + pctymale + I(sqrt(wcon)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area + polpc:area + area:density"),
    as.formula("crimes ~ region + I(log(prbarr)) + polpc + I(polpc^2) + I(sqrt(density)) + taxpc + pctymale + I(sqrt(wcon)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + polpc:area + area:density")))
# Out:
#   SEP        MSEP      RMSEP
# 1 7366934146 818548238 27842.869
# 2  189134487  21014943  4488.199
# 3  218432097  24270233  4869.731

# %%
library(tidyverse)
library(caret)
library(leaps)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.2.1 --
# v ggplot2 3.3.5     v purrr   0.3.4
# v tibble  3.1.1     v dplyr   1.0.6
# v tidyr   1.1.3     v stringr 1.4.0
# v readr   1.4.0     v forcats 0.5.1
# Warning message:
# "package 'tibble' was built under R version 3.6.3"Warning message:
# "package 'tidyr' was built under R version 3.6.3"Warning message:
# "package 'readr' was built under R version 3.6.3"Warning message:
# "package 'purrr' was built under R version 3.6.3"Warning message:
# "package 'dplyr' was built under R version 3.6.3"Warning message:
# "package 'forcats' was built under R version 3.6.3"-- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# Loading required package: lattice
#
# Attaching package: 'caret'
#
# The following object is masked from 'package:purrr':
#
#     lift

# %%
crimesWithoutCounty = crimes[-c(length(crimes))]

# %%
# http://www.sthda.com/english/articles/37-model-selection-essentials-in-r/154-stepwise-regression-essentials-in-r/
# Set seed for reproducibility
set.seed(123)
# Set up repeated k-fold cross-validation
train.control <- trainControl(method = "cv", number = 10)
# Train the model
step.model <- train(crimes ~ region + I(log(prbarr)) + prbpris + I(prbpris^2) + polpc + I(polpc^2) + I(sqrt(density)) + taxpc + pctymale + I(sqrt(wcon)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area, data = crimesWithoutCounty,
                    method = "leapBackward", tuneGrid = data.frame(nvmax = 1:14), trControl = train.control
                    )
step.model$results
# Out:
#    nvmax RMSE     Rsquared  MAE      RMSESD    RsquaredSD MAESD
# 1   1    2537.762 0.8086433 1739.993 1259.4128 0.1475060  471.1725
# 2   2    2449.376 0.8054067 1789.693 1053.4130 0.1256604  492.3959
# 3   3    1863.759 0.8107342 1451.303  540.0772 0.1915392  342.1926
# 4   4    1480.572 0.8667161 1145.947  447.6577 0.1520227  222.1805
# 5   5    1352.564 0.8441434 1056.401  468.5989 0.2186619  278.5928
# 6   6    1295.862 0.8587784 1022.345  464.5578 0.1894103  276.6456
# 7   7    1307.519 0.8692981 1014.339  529.6800 0.1805825  348.5859
# 8   8    1327.780 0.8692171 1041.217  516.5700 0.1823720  367.2351
# 9   9    1353.843 0.8686500 1060.964  526.8059 0.1815015  373.9208
# 10 10    1381.352 0.8627982 1086.035  521.0485 0.1867641  376.3769
# 11 11    1395.742 0.8600846 1099.166  516.5545 0.1907684  367.0877
# 12 12    1396.396 0.8607061 1096.724  518.2933 0.1883995  368.1070
# 13 13    1400.476 0.8605281 1094.129  530.0544 0.1883549  375.1696
# ...

# %%
step.model$bestTune
# Out:
#   nvmax
# 6 6

# %%
coef(step.model$finalModel, 5)
# Out:
#      (Intercept) I(sqrt(density))    I(sqrt(wser))             wtrd
#     48859.005569       839.671777      -657.929147      -581.696209
#        I(wtrd^2)             area
#         1.698183         6.033737

# %%
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region + I(log(prbarr)) + prbpris + I(prbpris^2) + polpc + I(polpc^2) + I(sqrt(density)) 
                + taxpc + pctymale + I(sqrt(wcon)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area + polpc:area + area:density"),
    as.formula("crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area"),
    as.formula("crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area + polpc:area + area:density")
    ))
# Out:
#   SEP       MSEP     RMSEP
# 1 862276600 95808511 9768.132
# 2 167827279 18647475 4179.796
# 3 113866024 12651780 3457.341

# %%
crimesglm1.1 = glm(crimes ~ I(prbpris^2), data=crimes, family=poisson(link="log"))
crimesglm1.2 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)), data=crimes, family=poisson(link="log"))
crimesglm1.3 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)), data=crimes, family=poisson(link="log"))
crimesglm1.4 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd, data=crimes, family=poisson(link="log"))
crimesglm1.5 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2), data=crimes, family=poisson(link="log"))
crimesglm1.6 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area, data=crimes, family=poisson(link="log"))

anova(crimesglm1.1, crimesglm1.2, crimesglm1.3, crimesglm1.4, crimesglm1.5, crimesglm1.6, test="LRT")
# Out:
#   Resid. Df Resid. Dev Df Deviance   Pr(>Chi)
# 1 88        419496.97  NA         NA NA
# 2 87         60978.37   1 358518.605  0
# 3 86         57736.13   1   3242.235  0
# 4 85         56100.75   1   1635.381  0
# 5 84         52782.46   1   3318.297  0
# 6 83         19226.11   1  33556.347  0

# %%
crimesglm1.1 = glm(crimes ~ I(prbpris^2), data=crimes, family=poisson(link="log"))
crimesglm1.2 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)), data=crimes, family=poisson(link="log"))
crimesglm1.3 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)), data=crimes, family=poisson(link="log"))
crimesglm1.4 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd, data=crimes, family=poisson(link="log"))
crimesglm1.5 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2), data=crimes, family=poisson(link="log"))
crimesglm1.6 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area, data=crimes, family=poisson(link="log"))
crimesglm1.7 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area + polpc:area, data=crimes, family=poisson(link="log"))
crimesglm1.8 = glm(crimes ~ I(prbpris^2) + I(sqrt(density)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area + polpc:area + area:density, data=crimes, family=poisson(link="log"))

anova(crimesglm1.1, crimesglm1.2, crimesglm1.3, crimesglm1.4, crimesglm1.5, crimesglm1.6, crimesglm1.7, crimesglm1.8, test="LRT")
# Out:
#   Resid. Df Resid. Dev Df Deviance     Pr(>Chi)
# 1 88        419496.97  NA           NA            NA
# 2 87         60978.37   1 358518.60467  0.000000e+00
# 3 86         57736.13   1   3242.23515  0.000000e+00
# 4 85         56100.75   1   1635.38055  0.000000e+00
# 5 84         52782.46   1   3318.29691  0.000000e+00
# 6 83         19226.11   1  33556.34700  0.000000e+00
# 7 82         19147.08   1     79.02696  6.126797e-19
# 8 81         17977.68   1   1169.40809 2.715481e-256

# %%
#Anfang Zusammenhänge
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region"),
    as.formula("crimes ~ region + area + density + pctmin + polpc + prbarr + prbpris + wcon + wfir + wser + wtrd"),
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2)")
))
# Out:
#   SEP        MSEP      RMSEP
# 1 2170530515 241170057 15528.768
# 2 8692690305 965854478 30480.822
# 3  304348797  33816533  5765.326
# 4  267308964  29700996  5369.317

# %%
# http://www.sthda.com/english/articles/37-model-selection-essentials-in-r/154-stepwise-regression-essentials-in-r/
# Set seed for reproducibility
set.seed(123)
# Set up repeated k-fold cross-validation
train.control <- trainControl(method = "cv", number = 10)
# Train the model
step.model <- train(crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr))
                    + I(sqrt(wcon)) + wtrd + I(wtrd^2), data = crimesWithoutCounty,
                    method = "leapBackward", tuneGrid = data.frame(nvmax = 1:10), trControl = train.control
                    )
step.model$results
# Out:
#    nvmax RMSE     Rsquared  MAE      RMSESD    RsquaredSD MAESD
# 1   1    2537.762 0.8086433 1739.993 1259.4128 0.1475060  471.1725
# 2   2    2449.376 0.8054067 1789.693 1053.4130 0.1256604  492.3959
# 3   3    1863.759 0.8107342 1451.303  540.0772 0.1915392  342.1926
# 4   4    1480.572 0.8667161 1145.947  447.6577 0.1520227  222.1805
# 5   5    1405.051 0.8738836 1052.770  455.2327 0.1768425  295.8838
# 6   6    1510.445 0.8693324 1130.531  490.0385 0.1668349  343.6870
# 7   7    1531.551 0.8632424 1141.703  494.7637 0.1817316  343.0945
# 8   8    1527.640 0.8611759 1143.490  486.1383 0.1834432  334.3939
# 9   9    1558.278 0.8591645 1163.812  543.0100 0.1805682  349.4598
# 10 10    1549.529 0.8611339 1159.520  557.9537 0.1774064  361.2207

# %%
step.model$bestTune
# Out:
#   nvmax
# 5 5

# %%
coef(step.model$finalModel, 5)
# Out:
#      (Intercept)             area I(sqrt(density))  I(sqrt(pctmin))
#     42434.704177         5.340239       785.612173       247.105057
#             wtrd        I(wtrd^2)
#      -603.139030         1.725559

# %%
#Verfeinerung Zusammenhänge
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2)"),
    #I(density*area)
    as.formula("crimes ~ I(density*area) + region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ I(density*area) + area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2)"),
    #density*area
    as.formula("crimes ~ density*area + region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ density*area + area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2)")
))
# Out:
#   SEP       MSEP     RMSEP
# 1 267308964 29700996 5369.317
# 2 157053141 17450349 4020.416
# 3 133909669 14878852 3724.919
# 4 143615471 15957275 3884.638
# 5 271294037 30143782 5447.607
# 6 198024912 22002768 4672.403

# %%
#Verfeinerung Zusammenhänge
eval(100, 9, 5, crimes, c(
    #area:density + polpc:area
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2) + area:density + polpc:area"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2) + area:density + polpc:area"),
    #area:density
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2) + area:density"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2) + area:density"),
    #polpc:area
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + I(sqrt(wcon)) + wtrd + I(wtrd^2) + polpc:area"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin)) + wtrd + I(wtrd^2) + polpc:area")
))
# Out:
#   SEP       MSEP     RMSEP
# 1 136728331 15192037 3784.481
# 2 165860241 18428916 4143.400
# 3 133909669 14878852 3724.919
# 4 143615471 15957275 3884.638
# 5 165657990 18406443 4235.226
# 6 222195668 24688408 4764.043

# %%
# http://www.sthda.com/english/articles/37-model-selection-essentials-in-r/154-stepwise-regression-essentials-in-r/
# Set seed for reproducibility
set.seed(123)
# Set up repeated k-fold cross-validation
train.control <- trainControl(method = "cv", number = 10)
# Train the model
step.model <- train(crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2), data = crimesWithoutCounty,
                    method = "leapBackward", tuneGrid = data.frame(nvmax = 1:10), trControl = train.control
                    )
step.model$results
# Out:
#    nvmax RMSE     Rsquared  MAE       RMSESD    RsquaredSD MAESD
# 1   1    2537.762 0.8086433 1739.9934 1259.4128 0.1475060  471.1725
# 2   2    2449.376 0.8054067 1789.6931 1053.4130 0.1256604  492.3959
# 3   3    1863.759 0.8107342 1451.3030  540.0772 0.1915392  342.1926
# 4   4    1480.572 0.8667161 1145.9465  447.6577 0.1520227  222.1805
# 5   5    1372.136 0.8440336 1088.9640  473.6662 0.2186115  302.0983
# 6   6    1323.345 0.8538792 1016.8123  497.0165 0.2135037  391.2512
# 7   7    1218.059 0.8732559  969.1481  494.5226 0.1870034  343.7455
# 8   8    1220.505 0.8766429  953.5106  452.6010 0.1733973  295.6947
# 9   9    1314.291 0.8694403 1007.8932  508.4251 0.1857181  348.7093
# 10 10    1373.139 0.8651820 1032.8592  570.4620 0.1899606  370.4292

# %%
step.model$bestTune
# Out:
#   nvmax
# 7 7

# %%
coef(step.model$finalModel, 7)
# Out:
#      (Intercept)             area I(sqrt(density))  I(sqrt(pctmin))
#     46449.107906         5.502661       841.685461       226.741779
#     I(prbpris^2)    I(sqrt(wser))             wtrd        I(wtrd^2)
#     -5185.479270      -548.749451      -569.902741         1.667557

# %%
#Verfeinerung Zusammenhänge
eval(100, 9, 5, crimes, c(
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    #I(density*area)
    as.formula("crimes ~ I(density*area) + region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ I(density*area) + area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    #density*area
    as.formula("crimes ~ I(density*area) + region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2)"),
    as.formula("crimes ~ I(density*area) + area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2)")
))
# Out:
#   SEP       MSEP     RMSEP
# 1 304348797 33816533 5765.326
# 2 277540297 30837811 5220.144
# 3 160822082 17869120 4117.834
# 4 165254505 18361612 4130.171
# 5 160822082 17869120 4117.834
# 6 165254505 18361612 4130.171

# %%
#Verfeinerung Zusammenhänge
eval(100, 9, 5, crimes, c(
    #area:density + polpc:area
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area:density + polpc:area"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area:density + polpc:area"),
    #area:density
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area:density"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2) + area:density"),
    #polpc:area
    as.formula("crimes ~ region + area + I(sqrt(density)) + I(sqrt(pctmin)) + polpc + I(polpc^2) + I(log(prbarr)) + prbpris + I(prbpris^2) + I(sqrt(wcon)) + I(log(wfir)) + I(sqrt(wser)) + wtrd + I(wtrd^2) + polpc:area"),
    as.formula("crimes ~ area + I(sqrt(density)) + I(sqrt(pctmin))+ I(prbpris^2) + I(sqrt(wser)) + wtrd + I(wtrd^2) + polpc:area")
))
# Out:
#   SEP       MSEP     RMSEP
# 1 164051977 18227997 4165.839
# 2 208738376 23193153 4555.521
# 3 160822082 17869120 4117.834
# 4 165254505 18361612 4130.171
# 5 235600159 26177795 5062.692
# 6 432020281 48002253 6482.837
