# %%
crimes.data = read.csv('../data/crimes.csv')
crimes.data$population = crimes.data$area * crimes.data$density
crimes.data$crime_rate = crimes.data$crime / crimes.data$population
crimes.data
# Out:
#     crimes prbarr    prbpris  polpc     density   area    taxpc    region
# 1    3901  0.289696  0.472222 0.0017868 230.71590 423.943 25.69763 central
# 2     416  0.202899  0.465753 0.0005939  97.68340 259.994 14.56088 central
# 3      91  0.406593  0.500000 0.0008209  41.27659 235.059 18.63060 west
# 4     562  0.431095  0.431373 0.0014327  48.21764 531.452 38.24473 central
# 5     170  0.631579  0.383333 0.0008353  53.05164 426.135 16.85321 west
# 6     275  0.369650  0.226415 0.0019067  59.10931 247.087 22.32144 west
# 7    1237  0.319665  0.500000 0.0012070  49.75787 827.192 20.10284 other
# 8     354  0.453258  0.489130 0.0009521  30.09986 699.270 21.63124 other
# 9     569  0.483986  0.460317 0.0013272  34.92605 874.328 24.73512 other
# 10    828  0.326196  0.404580 0.0019298  43.37209 846.973 53.86683 other
# 11   5663  0.262854  0.541096 0.0018014 246.13050 656.672 25.49358 west
# 12   2351  0.194303  0.439394 0.0014249 145.23810 507.099 17.68813 west
# ...

# %%
x = lm(paste('crimes~','region'), crimes.data)
#plot(paste0('crimes~','region'), crimes.data)
#plot(crimes~region,crimes.data)
plot(x,which=1)
# Out:
# Plot with title ""

# %%
parameters = c('prbarr','polpc','density','area','taxpc','region','pctmin','pctymale','wcon','wsta','wser','wtrd','wfir','population')
for (p in parameters)
{
    #if (p == 'region') {next}
    #x = paste0()
    #plot(m, which=1)
    m = lm(paste0('crime_rate~',p), crimes.data)
    plot(crimes.data[,p], crimes.data$crime_rate, xlab=p,ylab='crime rate')
    abline(m,col='red')
    #matlines(crimes.data, )
    #pred1 = predict(m, interval="prediction", newdata=crimes.data)
    #par(new=TRUE)
    #plot(crimes.data[,p], pred1[,2], col=2, type="l")
    #par(new=TRUE)
    #plot(crimes.data[,p], pred1[,3], col=2,type="l")
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# Warning message in abline(m, col = "red"):
# "only using the first two of 3 regression coefficients"
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
seq(1,10,2)
# Out:
# [1] 1 3 5 7 9
