# %%
crimes <- read.csv("data/crimes.csv")
crimes
# Out:
#    crimes prbarr    prbpris  polpc     density   area    taxpc    region
# 1   3901  0.289696  0.472222 0.0017868 230.71590 423.943 25.69763 central
# 2    416  0.202899  0.465753 0.0005939  97.68340 259.994 14.56088 central
# 3     91  0.406593  0.500000 0.0008209  41.27659 235.059 18.63060 west
# 4    562  0.431095  0.431373 0.0014327  48.21764 531.452 38.24473 central
# 5    170  0.631579  0.383333 0.0008353  53.05164 426.135 16.85321 west
# 6    275  0.369650  0.226415 0.0019067  59.10931 247.087 22.32144 west
# 7   1237  0.319665  0.500000 0.0012070  49.75787 827.192 20.10284 other
# 8    354  0.453258  0.489130 0.0009521  30.09986 699.270 21.63124 other
# 9    569  0.483986  0.460317 0.0013272  34.92605 874.328 24.73512 other
# 10   828  0.326196  0.404580 0.0019298  43.37209 846.973 53.86683 other
# 11  5663  0.262854  0.541096 0.0018014 246.13050 656.672 25.49358 west
# 12  2351  0.194303  0.439394 0.0014249 145.23810 507.099 17.68813 west
# ...

# %%
crimes.glm <- glm(crimes~1+prbarr+density+region, data=crimes, family=poisson(link="log"))
crimes.glm
# Out:
# Call:  glm(formula = crimes ~ 1 + prbarr + density + region, family = poisson(link = "log"),
#     data = crimes)
#
# Coefficients:
# (Intercept)       prbarr      density  regionother   regionwest
#    7.738299    -2.228805     0.004203     0.017798    -0.600784
#
# Degrees of Freedom: 89 Total (i.e. Null);  85 Residual
# Null Deviance:	    424300
# Residual Deviance: 79230 	AIC: 80050

# %%
summary(crimes.glm)
# Out:
# Call:
# glm(formula = crimes ~ 1 + prbarr + prbpris + polpc + density +
#     area, family = poisson(link = "log"), data = crimes)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -50.601  -21.832   -7.051    9.700   52.067
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  5.598e+00  1.758e-02  318.35   <2e-16 ***
# prbarr      -2.325e+00  2.821e-02  -82.42   <2e-16 ***
# prbpris      2.393e+00  2.791e-02   85.73   <2e-16 ***
# polpc       -6.035e+01  2.896e+00  -20.84   <2e-16 ***
# density      4.756e-03  8.917e-06  533.39   <2e-16 ***
# area         1.884e-03  1.104e-05  170.73   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for poisson family taken to be 1)
#
#     Null deviance: 424280  on 89  degrees of freedom
# Residual deviance:  48982  on 84  degrees of freedom
# AIC: 49803
#
# Number of Fisher Scoring iterations: 5

# %%
plot(crimes.glm)
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”
